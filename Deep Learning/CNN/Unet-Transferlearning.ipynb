# %% [markdown]
# ### CNN
#
# Chúng ta sẽ tiến hành xâu dựng mô hình Unet
#
# Mô hình cần xây dựng là mô hình segmentation tóc.
#
# Xây dựng chương trình với Tensorflow 2.3

# %%
! nvidia-smi
# Out:
# Fri Sep 18 00:20:09 2020
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 450.66       Driver Version: 418.67       CUDA Version: 10.1     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla V100-SXM2...  Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   32C    P0    23W / 300W |      0MiB / 16130MiB |      0%      Default |
# |                               |                      |                 ERR! |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                                  |
# |  GPU   GI   CI        PID   Type   Process name                  GPU Memory |
# |        ID   ID                                                   Usage      |
# |=============================================================================|
# |  No running processes found                                                 |
# +-----------------------------------------------------------------------------+

# %% [markdown]
# ### Tiến hành tải và giải dữ liệu
#
# Link dữ liệu [tại đây](https://drive.google.com/drive/folders/1qnp7-DcLSxGi4rI9LGCJC_LR_SwvHeoB?usp=sharing)
#
# Có hai loại dữ liệu có kích thước nhỏ và lớn
#
# Code tải dữ liệu:
# * Nhỏ: ```wget --load-cookies /tmp/cookies.txt "https://docs.google.com/uc?export=download&confirm=$(wget --quiet --save-cookies /tmp/cookies.txt --keep-session-cookies --no-check-certificate 'https://docs.google.com/uc?export=download&id=1-9eY2slA6ZmdBLLEExdxhLcavm0bPZua' -O- | sed -rn 's/.*confirm=([0-9A-Za-z_]+).*/\1\n/p')&id=1-9eY2slA6ZmdBLLEExdxhLcavm0bPZua" -O dataset.zip && rm -rf /tmp/cookies.txt```
#
# * Lớn: ```wget --load-cookies /tmp/cookies.txt "https://docs.google.com/uc?export=download&confirm=$(wget --quiet --save-cookies /tmp/cookies.txt --keep-session-cookies --no-check-certificate 'https://docs.google.com/uc?export=download&id=1jmfiZGD0tpYxKvJX18DLzugQw2KgpWqu' -O- | sed -rn 's/.*confirm=([0-9A-Za-z_]+).*/\1\n/p')&id=1jmfiZGD0tpYxKvJX18DLzugQw2KgpWqu" -O dataset-large.zip && rm -rf /tmp/cookies.txt
# ```

# %%
! wget --load-cookies /tmp/cookies.txt "https://docs.google.com/uc?export=download&confirm=$(wget --quiet --save-cookies /tmp/cookies.txt --keep-session-cookies --no-check-certificate 'https://docs.google.com/uc?export=download&id=1jmfiZGD0tpYxKvJX18DLzugQw2KgpWqu' -O- | sed -rn 's/.*confirm=([0-9A-Za-z_]+).*/\1\n/p')&id=1jmfiZGD0tpYxKvJX18DLzugQw2KgpWqu" -O dataset-large.zip && rm -rf /tmp/cookies.txt
# Out:
# --2020-09-18 00:19:10--  https://docs.google.com/uc?export=download&confirm=Ursu&id=1jmfiZGD0tpYxKvJX18DLzugQw2KgpWqu
# Resolving docs.google.com (docs.google.com)... 108.177.126.113, 108.177.126.138, 108.177.126.101, ...
# Connecting to docs.google.com (docs.google.com)|108.177.126.113|:443... connected.
# HTTP request sent, awaiting response... 302 Moved Temporarily
# Location: https://doc-10-ao-docs.googleusercontent.com/docs/securesc/obhu9qbp71vk3cki3rdjpok799l8mmeq/f4is42958arja7735hf378r43jcl7af8/1600388325000/04205927457588895310/14820508183631267198Z/1jmfiZGD0tpYxKvJX18DLzugQw2KgpWqu?e=download [following]
# --2020-09-18 00:19:10--  https://doc-10-ao-docs.googleusercontent.com/docs/securesc/obhu9qbp71vk3cki3rdjpok799l8mmeq/f4is42958arja7735hf378r43jcl7af8/1600388325000/04205927457588895310/14820508183631267198Z/1jmfiZGD0tpYxKvJX18DLzugQw2KgpWqu?e=download
# Resolving doc-10-ao-docs.googleusercontent.com (doc-10-ao-docs.googleusercontent.com)... 108.177.119.132, 2a00:1450:4013:c00::84
# Connecting to doc-10-ao-docs.googleusercontent.com (doc-10-ao-docs.googleusercontent.com)|108.177.119.132|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://docs.google.com/nonceSigner?nonce=s115ghctsq7ac&continue=https://doc-10-ao-docs.googleusercontent.com/docs/securesc/obhu9qbp71vk3cki3rdjpok799l8mmeq/f4is42958arja7735hf378r43jcl7af8/1600388325000/04205927457588895310/14820508183631267198Z/1jmfiZGD0tpYxKvJX18DLzugQw2KgpWqu?e%3Ddownload&hash=s2gq0obua54d11smbjh2repo39up8l4d [following]
# --2020-09-18 00:19:10--  https://docs.google.com/nonceSigner?nonce=s115ghctsq7ac&continue=https://doc-10-ao-docs.googleusercontent.com/docs/securesc/obhu9qbp71vk3cki3rdjpok799l8mmeq/f4is42958arja7735hf378r43jcl7af8/1600388325000/04205927457588895310/14820508183631267198Z/1jmfiZGD0tpYxKvJX18DLzugQw2KgpWqu?e%3Ddownload&hash=s2gq0obua54d11smbjh2repo39up8l4d
# Connecting to docs.google.com (docs.google.com)|108.177.126.113|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://doc-10-ao-docs.googleusercontent.com/docs/securesc/obhu9qbp71vk3cki3rdjpok799l8mmeq/f4is42958arja7735hf378r43jcl7af8/1600388325000/04205927457588895310/14820508183631267198Z/1jmfiZGD0tpYxKvJX18DLzugQw2KgpWqu?e=download&nonce=s115ghctsq7ac&user=14820508183631267198Z&hash=fj7dn90hp90phk2kp7e3n82n6kjgadrj [following]
# --2020-09-18 00:19:10--  https://doc-10-ao-docs.googleusercontent.com/docs/securesc/obhu9qbp71vk3cki3rdjpok799l8mmeq/f4is42958arja7735hf378r43jcl7af8/1600388325000/04205927457588895310/14820508183631267198Z/1jmfiZGD0tpYxKvJX18DLzugQw2KgpWqu?e=download&nonce=s115ghctsq7ac&user=14820508183631267198Z&hash=fj7dn90hp90phk2kp7e3n82n6kjgadrj
# Connecting to doc-10-ao-docs.googleusercontent.com (doc-10-ao-docs.googleusercontent.com)|108.177.119.132|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [application/zip]
# Saving to: ‘dataset-large.zip’
#
# dataset-large.zip       [               <=>  ]   2.54G  61.8MB/s    in 47s
#
# 2020-09-18 00:19:57 (55.8 MB/s) - ‘dataset-large.zip’ saved [2732965694]

# %%
! mkdir dataset
! mkdir trained_model

# %%
! unzip /content/dataset-large.zip -d /content/dataset/
# Out:
# Kết quả truyền trực tuyến bị cắt bớt đến 5000 dòng cuối.
#   inflating: /content/dataset/Original/Training/16759.jpg
#   inflating: /content/dataset/Original/Training/11197.jpg
#   inflating: /content/dataset/Original/Training/13645.jpg
#   inflating: /content/dataset/Original/Training/1439.jpg
#   inflating: /content/dataset/Original/Training/28164.jpg
#   inflating: /content/dataset/Original/Training/18553.jpg
#   inflating: /content/dataset/Original/Training/28315.jpg
#   inflating: /content/dataset/Original/Training/27458.jpg
#   inflating: /content/dataset/Original/Training/17641.jpg
#   inflating: /content/dataset/Original/Training/24473.jpg
#   inflating: /content/dataset/Original/Training/14663.jpg
#   inflating: /content/dataset/Original/Training/2058.jpg
#   inflating: /content/dataset/Original/Training/1749.jpg
#   inflating: /content/dataset/Original/Training/13647.jpg
#   inflating: /content/dataset/Original/Training/11681.jpg
#   inflating: /content/dataset/Original/Training/8658.jpg
#   inflating: /content/dataset/Original/Training/10693.jpg
#   inflating: /content/dataset/Original/Training/18417.jpg
#   inflating: /content/dataset/Original/Training/7466.jpg
#   inflating: /content/dataset/Original/Training/22271.jpg
#   inflating: /content/dataset/Original/Training/28131.jpg
#   inflating: /content/dataset/Original/Training/22787.jpg
#   inflating: /content/dataset/Original/Training/1114.jpg
#   inflating: /content/dataset/Original/Training/20734.jpg
#   inflating: /content/dataset/Original/Training/28656.jpg
#   inflating: /content/dataset/Original/Training/12317.jpg
#   inflating: /content/dataset/Original/Training/20299.jpg
#   inflating: /content/dataset/Original/Training/23285.jpg
#   inflating: /content/dataset/Original/Training/21263.jpg
#   inflating: /content/dataset/Original/Training/3599.jpg
#   inflating: /content/dataset/Original/Training/13705.jpg
#   inflating: /content/dataset/Original/Training/2789.jpg
#   inflating: /content/dataset/Original/Training/5368.jpg
#   inflating: /content/dataset/Original/Training/10799.jpg
#   inflating: /content/dataset/Original/Training/13925.jpg
#   inflating: /content/dataset/Original/Training/15539.jpg
#   inflating: /content/dataset/Original/Training/19714.jpg
#   inflating: /content/dataset/Original/Training/16471.jpg
#   inflating: /content/dataset/Original/Training/13897.jpg
#   inflating: /content/dataset/Original/Training/18158.jpg
#   inflating: /content/dataset/Original/Training/28348.jpg
#   inflating: /content/dataset/Original/Training/16636.jpg
#   inflating: /content/dataset/Original/Training/2180.jpg
#   inflating: /content/dataset/Original/Training/18232.jpg
#   inflating: /content/dataset/Original/Training/2164.jpg
#   inflating: /content/dataset/Original/Training/23478.jpg
#   inflating: /content/dataset/Original/Training/13139.jpg
#   inflating: /content/dataset/Original/Training/6505.jpg
#   inflating: /content/dataset/Original/Training/7190.jpg
#   inflating: /content/dataset/Original/Training/5873.jpg
#   inflating: /content/dataset/Original/Training/27711.jpg
#   inflating: /content/dataset/Original/Training/4503.jpg
#   inflating: /content/dataset/Original/Training/24713.jpg
#   inflating: /content/dataset/Original/Training/13404.jpg
#   inflating: /content/dataset/Original/Training/4905.jpg
#   inflating: /content/dataset/Original/Training/1402.jpg
#   inflating: /content/dataset/Original/Training/9689.jpg
#   inflating: /content/dataset/Original/Training/2651.jpg
#   inflating: /content/dataset/Original/Training/13307.jpg
#   inflating: /content/dataset/Original/Training/10825.jpg
#   inflating: /content/dataset/Original/Training/4433.jpg
#   inflating: /content/dataset/Original/Training/21103.jpg
#   inflating: /content/dataset/Original/Training/1724.jpg
#   inflating: /content/dataset/Original/Training/28244.jpg
#   inflating: /content/dataset/Original/Training/12946.jpg
#   inflating: /content/dataset/Original/Training/20517.jpg
#   inflating: /content/dataset/Original/Training/7616.jpg
#   inflating: /content/dataset/Original/Training/4359.jpg
#   inflating: /content/dataset/Original/Training/18436.jpg
#   inflating: /content/dataset/Original/Training/2011.jpg
#   inflating: /content/dataset/Original/Training/11076.jpg
#   inflating: /content/dataset/Original/Training/1661.jpg
#   inflating: /content/dataset/Original/Training/13552.jpg
#   inflating: /content/dataset/Original/Training/12530.jpg
#   inflating: /content/dataset/Original/Training/24154.jpg
#   inflating: /content/dataset/Original/Training/20634.jpg
#   inflating: /content/dataset/Original/Training/15176.jpg
#   inflating: /content/dataset/Original/Training/28545.jpg
#   inflating: /content/dataset/Original/Training/26373.jpg
#   inflating: /content/dataset/Original/Training/16183.jpg
#   inflating: /content/dataset/Original/Training/22911.jpg
#   inflating: /content/dataset/Original/Training/11293.jpg
#   inflating: /content/dataset/Original/Training/1732.jpg
#   inflating: /content/dataset/Original/Training/19428.jpg
#   inflating: /content/dataset/Original/Training/3361.jpg
#   inflating: /content/dataset/Original/Training/4858.jpg
#   inflating: /content/dataset/Original/Training/28296.jpg
#   inflating: /content/dataset/Original/Training/7029.jpg
#   inflating: /content/dataset/Original/Training/24134.jpg
#   inflating: /content/dataset/Original/Training/25033.jpg
#   inflating: /content/dataset/Original/Training/10295.jpg
#   inflating: /content/dataset/Original/Training/22303.jpg
#   inflating: /content/dataset/Original/Training/9433.jpg
#   inflating: /content/dataset/Original/Training/7034.jpg
#   inflating: /content/dataset/Original/Training/16066.jpg
#   inflating: /content/dataset/Original/Training/11540.jpg
#   inflating: /content/dataset/Original/Training/18084.jpg
#   inflating: /content/dataset/Original/Training/16497.jpg
#   inflating: /content/dataset/Original/Training/29185.jpg
#   inflating: /content/dataset/Original/Training/25547.jpg
#   inflating: /content/dataset/Original/Training/17393.jpg
#   inflating: /content/dataset/Original/Training/1719.jpg
#   inflating: /content/dataset/Original/Training/29735.jpg
#   inflating: /content/dataset/Original/Training/7387.jpg
#   inflating: /content/dataset/Original/Training/1804.jpg
#   inflating: /content/dataset/Original/Training/4543.jpg
#   inflating: /content/dataset/Original/Training/16727.jpg
#   inflating: /content/dataset/Original/Training/18820.jpg
#   inflating: /content/dataset/Original/Training/21859.jpg
#   inflating: /content/dataset/Original/Training/2906.jpg
#   inflating: /content/dataset/Original/Training/3592.jpg
#   inflating: /content/dataset/Original/Training/3425.jpg
#   inflating: /content/dataset/Original/Training/8903.jpg
#   inflating: /content/dataset/Original/Training/24023.jpg
#   inflating: /content/dataset/Original/Training/7393.jpg
#   inflating: /content/dataset/Original/Training/12954.jpg
#   inflating: /content/dataset/Original/Training/13781.jpg
#   inflating: /content/dataset/Original/Training/8881.jpg
#   inflating: /content/dataset/Original/Training/27202.jpg
#   inflating: /content/dataset/Original/Training/22368.jpg
#   inflating: /content/dataset/Original/Training/20164.jpg
#   inflating: /content/dataset/Original/Training/22496.jpg
#   inflating: /content/dataset/Original/Training/24182.jpg
#   inflating: /content/dataset/Original/Training/19781.jpg
#   inflating: /content/dataset/Original/Training/2817.jpg
#   inflating: /content/dataset/Original/Training/1154.jpg
#   inflating: /content/dataset/Original/Training/5731.jpg
#   inflating: /content/dataset/Original/Training/2153.jpg
#   inflating: /content/dataset/Original/Training/24138.jpg
#   inflating: /content/dataset/Original/Training/9095.jpg
#   inflating: /content/dataset/Original/Training/5474.jpg
#   inflating: /content/dataset/Original/Training/20568.jpg
#   inflating: /content/dataset/Original/Training/10445.jpg
#   inflating: /content/dataset/Original/Training/12453.jpg
#   inflating: /content/dataset/Original/Training/22304.jpg
#   inflating: /content/dataset/Original/Training/5282.jpg
#   inflating: /content/dataset/Original/Training/20271.jpg
#   inflating: /content/dataset/Original/Training/11771.jpg
#   inflating: /content/dataset/Original/Training/4764.jpg
#   inflating: /content/dataset/Original/Training/26229.jpg
#   inflating: /content/dataset/Original/Training/9484.jpg
#   inflating: /content/dataset/Original/Training/5220.jpg
#   inflating: /content/dataset/Original/Training/4067.jpg
#   inflating: /content/dataset/Original/Training/26189.jpg
#   inflating: /content/dataset/Original/Training/23169.jpg
#   inflating: /content/dataset/Original/Training/4231.jpg
#   inflating: /content/dataset/Original/Training/21439.jpg
#   inflating: /content/dataset/Original/Training/19815.jpg
#   inflating: /content/dataset/Original/Training/22073.jpg
#   inflating: /content/dataset/Original/Training/22276.jpg
#   inflating: /content/dataset/Original/Training/21152.jpg
#   inflating: /content/dataset/Original/Training/1997.jpg
#   inflating: /content/dataset/Original/Training/9505.jpg
#   inflating: /content/dataset/Original/Training/15419.jpg
#   inflating: /content/dataset/Original/Training/1575.jpg
#   inflating: /content/dataset/Original/Training/6942.jpg
#   inflating: /content/dataset/Original/Training/23989.jpg
#   inflating: /content/dataset/Original/Training/26472.jpg
#   inflating: /content/dataset/Original/Training/23411.jpg
#   inflating: /content/dataset/Original/Training/17685.jpg
#   inflating: /content/dataset/Original/Training/12294.jpg
#   inflating: /content/dataset/Original/Training/5939.jpg
#   inflating: /content/dataset/Original/Training/24216.jpg
#   inflating: /content/dataset/Original/Training/5050.jpg
#   inflating: /content/dataset/Original/Training/12135.jpg
#   inflating: /content/dataset/Original/Training/23384.jpg
#   inflating: /content/dataset/Original/Training/5634.jpg
#   inflating: /content/dataset/Original/Training/18393.jpg
#   inflating: /content/dataset/Original/Training/15221.jpg
#   inflating: /content/dataset/Original/Training/2743.jpg
#   inflating: /content/dataset/Original/Training/24912.jpg
#   inflating: /content/dataset/Original/Training/5157.jpg
#   inflating: /content/dataset/Original/Training/13392.jpg
#   inflating: /content/dataset/Original/Training/23692.jpg
#   inflating: /content/dataset/Original/Training/19760.jpg
#   inflating: /content/dataset/Original/Training/27178.jpg
#   inflating: /content/dataset/Original/Training/24397.jpg
#   inflating: /content/dataset/Original/Training/17226.jpg
#   inflating: /content/dataset/Original/Training/16899.jpg
#   inflating: /content/dataset/Original/Training/28557.jpg
#   inflating: /content/dataset/Original/Training/14995.jpg
#   inflating: /content/dataset/Original/Training/11492.jpg
#   inflating: /content/dataset/Original/Training/28542.jpg
#   inflating: /content/dataset/Original/Training/20954.jpg
#   inflating: /content/dataset/Original/Training/14787.jpg
#   inflating: /content/dataset/Original/Training/2243.jpg
#   inflating: /content/dataset/Original/Training/10808.jpg
#   inflating: /content/dataset/Original/Training/29050.jpg
#   inflating: /content/dataset/Original/Training/25906.jpg
#   inflating: /content/dataset/Original/Training/22253.jpg
#   inflating: /content/dataset/Original/Training/24961.jpg
#   inflating: /content/dataset/Original/Training/23328.jpg
#   inflating: /content/dataset/Original/Training/6224.jpg
#   inflating: /content/dataset/Original/Training/9328.jpg
#   inflating: /content/dataset/Original/Training/3983.jpg
#   inflating: /content/dataset/Original/Training/17677.jpg
#   inflating: /content/dataset/Original/Training/6172.jpg
#   inflating: /content/dataset/Original/Training/9707.jpg
#   inflating: /content/dataset/Original/Training/8130.jpg
#   inflating: /content/dataset/Original/Training/4998.jpg
#   inflating: /content/dataset/Original/Training/5126.jpg
#   inflating: /content/dataset/Original/Training/9821.jpg
#   inflating: /content/dataset/Original/Training/3933.jpg
#   inflating: /content/dataset/Original/Training/10685.jpg
#   inflating: /content/dataset/Original/Training/24705.jpg
#   inflating: /content/dataset/Original/Training/2809.jpg
#   inflating: /content/dataset/Original/Training/7990.jpg
#   inflating: /content/dataset/Original/Training/4530.jpg
#   inflating: /content/dataset/Original/Training/25729.jpg
#   inflating: /content/dataset/Original/Training/10827.jpg
#   inflating: /content/dataset/Original/Training/6551.jpg
#   inflating: /content/dataset/Original/Training/24550.jpg
#   inflating: /content/dataset/Original/Training/23253.jpg
#   inflating: /content/dataset/Original/Training/4604.jpg
#   inflating: /content/dataset/Original/Training/8255.jpg
#   inflating: /content/dataset/Original/Training/3545.jpg
#   inflating: /content/dataset/Original/Training/11178.jpg
#   inflating: /content/dataset/Original/Training/20026.jpg
#   inflating: /content/dataset/Original/Training/5428.jpg
#   inflating: /content/dataset/Original/Training/11112.jpg
#   inflating: /content/dataset/Original/Training/21306.jpg
#   inflating: /content/dataset/Original/Training/10242.jpg
#   inflating: /content/dataset/Original/Training/3609.jpg
#   inflating: /content/dataset/Original/Training/25725.jpg
#   inflating: /content/dataset/Original/Training/15684.jpg
#   inflating: /content/dataset/Original/Training/27867.jpg
#   inflating: /content/dataset/Original/Training/29444.jpg
#   inflating: /content/dataset/Original/Training/6261.jpg
#   inflating: /content/dataset/Original/Training/15397.jpg
#   inflating: /content/dataset/Original/Training/6170.jpg
#   inflating: /content/dataset/Original/Training/25171.jpg
#   inflating: /content/dataset/Original/Training/14364.jpg
#   inflating: /content/dataset/Original/Training/29289.jpg
#   inflating: /content/dataset/Original/Training/3412.jpg
#   inflating: /content/dataset/Original/Training/25581.jpg
#   inflating: /content/dataset/Original/Training/6327.jpg
#   inflating: /content/dataset/Original/Training/28438.jpg
#   inflating: /content/dataset/Original/Training/7189.jpg
#   inflating: /content/dataset/Original/Training/8259.jpg
#   inflating: /content/dataset/Original/Training/6120.jpg
#   inflating: /content/dataset/Original/Training/29502.jpg
#   inflating: /content/dataset/Original/Training/28528.jpg
#   inflating: /content/dataset/Original/Training/26903.jpg
#   inflating: /content/dataset/Original/Training/16613.jpg
#   inflating: /content/dataset/Original/Training/9686.jpg
#   inflating: /content/dataset/Original/Training/8994.jpg
#   inflating: /content/dataset/Original/Training/20835.jpg
#   inflating: /content/dataset/Original/Training/10672.jpg
#   inflating: /content/dataset/Original/Training/12236.jpg
#   inflating: /content/dataset/Original/Training/15681.jpg
#   inflating: /content/dataset/Original/Training/12849.jpg
#   inflating: /content/dataset/Original/Training/25812.jpg
#   inflating: /content/dataset/Original/Training/22033.jpg
#   inflating: /content/dataset/Original/Training/24764.jpg
#   inflating: /content/dataset/Original/Training/4933.jpg
#   inflating: /content/dataset/Original/Training/8513.jpg
#   inflating: /content/dataset/Original/Training/1795.jpg
#   inflating: /content/dataset/Original/Training/16974.jpg
#   inflating: /content/dataset/Original/Training/18951.jpg
#   inflating: /content/dataset/Original/Training/19068.jpg
#   inflating: /content/dataset/Original/Training/19433.jpg
#   inflating: /content/dataset/Original/Training/13678.jpg
#   inflating: /content/dataset/Original/Training/26112.jpg
#   inflating: /content/dataset/Original/Training/8790.jpg
#   inflating: /content/dataset/Original/Training/9589.jpg
#   inflating: /content/dataset/Original/Training/6812.jpg
#   inflating: /content/dataset/Original/Training/15680.jpg
#   inflating: /content/dataset/Original/Training/7247.jpg
#   inflating: /content/dataset/Original/Training/8350.jpg
#   inflating: /content/dataset/Original/Training/11668.jpg
#   inflating: /content/dataset/Original/Training/21633.jpg
#   inflating: /content/dataset/Original/Training/12497.jpg
#   inflating: /content/dataset/Original/Training/20926.jpg
#   inflating: /content/dataset/Original/Training/9303.jpg
#   inflating: /content/dataset/Original/Training/25755.jpg
#   inflating: /content/dataset/Original/Training/4206.jpg
#   inflating: /content/dataset/Original/Training/19263.jpg
#   inflating: /content/dataset/Original/Training/3797.jpg
#   inflating: /content/dataset/Original/Training/8116.jpg
#   inflating: /content/dataset/Original/Training/29482.jpg
#   inflating: /content/dataset/Original/Training/20934.jpg
#   inflating: /content/dataset/Original/Training/2213.jpg
#   inflating: /content/dataset/Original/Training/8077.jpg
#   inflating: /content/dataset/Original/Training/2883.jpg
#   inflating: /content/dataset/Original/Training/15035.jpg
#   inflating: /content/dataset/Original/Training/16861.jpg
#   inflating: /content/dataset/Original/Training/26454.jpg
#   inflating: /content/dataset/Original/Training/26174.jpg
#   inflating: /content/dataset/Original/Training/26870.jpg
#   inflating: /content/dataset/Original/Training/24589.jpg
#   inflating: /content/dataset/Original/Training/3415.jpg
#   inflating: /content/dataset/Original/Training/24035.jpg
#   inflating: /content/dataset/Original/Training/29402.jpg
#   inflating: /content/dataset/Original/Training/14566.jpg
#   inflating: /content/dataset/Original/Training/19498.jpg
#   inflating: /content/dataset/Original/Training/7851.jpg
#   inflating: /content/dataset/Original/Training/12657.jpg
#   inflating: /content/dataset/Original/Training/29418.jpg
#   inflating: /content/dataset/Original/Training/26618.jpg
#   inflating: /content/dataset/Original/Training/11400.jpg
#   inflating: /content/dataset/Original/Training/13540.jpg
#   inflating: /content/dataset/Original/Training/6318.jpg
#   inflating: /content/dataset/Original/Training/3871.jpg
#   inflating: /content/dataset/Original/Training/26015.jpg
#   inflating: /content/dataset/Original/Training/15389.jpg
#   inflating: /content/dataset/Original/Training/25502.jpg
#   inflating: /content/dataset/Original/Training/10205.jpg
#   inflating: /content/dataset/Original/Training/16368.jpg
#   inflating: /content/dataset/Original/Training/7236.jpg
#   inflating: /content/dataset/Original/Training/22159.jpg
#   inflating: /content/dataset/Original/Training/9908.jpg
#   inflating: /content/dataset/Original/Training/12826.jpg
#   inflating: /content/dataset/Original/Training/3504.jpg
#   inflating: /content/dataset/Original/Training/6897.jpg
#   inflating: /content/dataset/Original/Training/12361.jpg
#   inflating: /content/dataset/Original/Training/27636.jpg
#   inflating: /content/dataset/Original/Training/27921.jpg
#   inflating: /content/dataset/Original/Training/15404.jpg
#   inflating: /content/dataset/Original/Training/11316.jpg
#   inflating: /content/dataset/Original/Training/11566.jpg
#   inflating: /content/dataset/Original/Training/26551.jpg
#   inflating: /content/dataset/Original/Training/23450.jpg
#   inflating: /content/dataset/Original/Training/7074.jpg
#   inflating: /content/dataset/Original/Training/8493.jpg
#   inflating: /content/dataset/Original/Training/2415.jpg
#   inflating: /content/dataset/Original/Training/11812.jpg
#   inflating: /content/dataset/Original/Training/17926.jpg
#   inflating: /content/dataset/Original/Training/20831.jpg
#   inflating: /content/dataset/Original/Training/13157.jpg
#   inflating: /content/dataset/Original/Training/6475.jpg
#   inflating: /content/dataset/Original/Training/9424.jpg
#   inflating: /content/dataset/Original/Training/13846.jpg
#   inflating: /content/dataset/Original/Training/7142.jpg
#   inflating: /content/dataset/Original/Training/22862.jpg
#   inflating: /content/dataset/Original/Training/21917.jpg
#   inflating: /content/dataset/Original/Training/4114.jpg
#   inflating: /content/dataset/Original/Training/21305.jpg
#   inflating: /content/dataset/Original/Training/8419.jpg
#   inflating: /content/dataset/Original/Training/21930.jpg
#   inflating: /content/dataset/Original/Training/14900.jpg
#   inflating: /content/dataset/Original/Training/23951.jpg
#   inflating: /content/dataset/Original/Training/13458.jpg
#   inflating: /content/dataset/Original/Training/1949.jpg
#   inflating: /content/dataset/Original/Training/29182.jpg
#   inflating: /content/dataset/Original/Training/25700.jpg
#   inflating: /content/dataset/Original/Training/1683.jpg
#   inflating: /content/dataset/Original/Training/18051.jpg
#   inflating: /content/dataset/Original/Training/2197.jpg
#   inflating: /content/dataset/Original/Training/25069.jpg
#   inflating: /content/dataset/Original/Training/10469.jpg
#   inflating: /content/dataset/Original/Training/13365.jpg
#   inflating: /content/dataset/Original/Training/29116.jpg
#   inflating: /content/dataset/Original/Training/5343.jpg
#   inflating: /content/dataset/Original/Training/19056.jpg
#   inflating: /content/dataset/Original/Training/22757.jpg
#   inflating: /content/dataset/Original/Training/28879.jpg
#   inflating: /content/dataset/Original/Training/13926.jpg
#   inflating: /content/dataset/Original/Training/20441.jpg
#   inflating: /content/dataset/Original/Training/6286.jpg
#   inflating: /content/dataset/Original/Training/16700.jpg
#   inflating: /content/dataset/Original/Training/11121.jpg
#   inflating: /content/dataset/Original/Training/9429.jpg
#   inflating: /content/dataset/Original/Training/14579.jpg
#   inflating: /content/dataset/Original/Training/7149.jpg
#   inflating: /content/dataset/Original/Training/29310.jpg
#   inflating: /content/dataset/Original/Training/6992.jpg
#   inflating: /content/dataset/Original/Training/16824.jpg
#   inflating: /content/dataset/Original/Training/25803.jpg
#   inflating: /content/dataset/Original/Training/22847.jpg
#   inflating: /content/dataset/Original/Training/3602.jpg
#   inflating: /content/dataset/Original/Training/20274.jpg
#   inflating: /content/dataset/Original/Training/8238.jpg
#   inflating: /content/dataset/Original/Training/11010.jpg
#   inflating: /content/dataset/Original/Training/13662.jpg
#   inflating: /content/dataset/Original/Training/20542.jpg
#   inflating: /content/dataset/Original/Training/23948.jpg
#   inflating: /content/dataset/Original/Training/6173.jpg
#   inflating: /content/dataset/Original/Training/1523.jpg
#   inflating: /content/dataset/Original/Training/3182.jpg
#   inflating: /content/dataset/Original/Training/10784.jpg
#   inflating: /content/dataset/Original/Training/17867.jpg
#   inflating: /content/dataset/Original/Training/6965.jpg
#   inflating: /content/dataset/Original/Training/20862.jpg
#   inflating: /content/dataset/Original/Training/10122.jpg
#   inflating: /content/dataset/Original/Training/10800.jpg
#   inflating: /content/dataset/Original/Training/19391.jpg
#   inflating: /content/dataset/Original/Training/8366.jpg
#   inflating: /content/dataset/Original/Training/1237.jpg
#   inflating: /content/dataset/Original/Training/27362.jpg
#   inflating: /content/dataset/Original/Training/28156.jpg
#   inflating: /content/dataset/Original/Training/12197.jpg
#   inflating: /content/dataset/Original/Training/14914.jpg
#   inflating: /content/dataset/Original/Training/16467.jpg
#   inflating: /content/dataset/Original/Training/3170.jpg
#   inflating: /content/dataset/Original/Training/13132.jpg
#   inflating: /content/dataset/Original/Training/28908.jpg
#   inflating: /content/dataset/Original/Training/17203.jpg
#   inflating: /content/dataset/Original/Training/8996.jpg
#   inflating: /content/dataset/Original/Training/15914.jpg
#   inflating: /content/dataset/Original/Training/19475.jpg
#   inflating: /content/dataset/Original/Training/28541.jpg
#   inflating: /content/dataset/Original/Training/19689.jpg
#   inflating: /content/dataset/Original/Training/6728.jpg
#   inflating: /content/dataset/Original/Training/15213.jpg
#   inflating: /content/dataset/Original/Training/22540.jpg
#   inflating: /content/dataset/Original/Training/29367.jpg
#   inflating: /content/dataset/Original/Training/15660.jpg
#   inflating: /content/dataset/Original/Training/1044.jpg
#   inflating: /content/dataset/Original/Training/15679.jpg
#   inflating: /content/dataset/Original/Training/26908.jpg
#   inflating: /content/dataset/Original/Training/8953.jpg
#   inflating: /content/dataset/Original/Training/18625.jpg
#   inflating: /content/dataset/Original/Training/13822.jpg
#   inflating: /content/dataset/Original/Training/22818.jpg
#   inflating: /content/dataset/Original/Training/9079.jpg
#   inflating: /content/dataset/Original/Training/15813.jpg
#   inflating: /content/dataset/Original/Training/21821.jpg
#   inflating: /content/dataset/Original/Training/6624.jpg
#   inflating: /content/dataset/Original/Training/15675.jpg
#   inflating: /content/dataset/Original/Training/23407.jpg
#   inflating: /content/dataset/Original/Training/10112.jpg
#   inflating: /content/dataset/Original/Training/4017.jpg
#   inflating: /content/dataset/Original/Training/21254.jpg
#   inflating: /content/dataset/Original/Training/18492.jpg
#   inflating: /content/dataset/Original/Training/1550.jpg
#   inflating: /content/dataset/Original/Training/13209.jpg
#   inflating: /content/dataset/Original/Training/14028.jpg
#   inflating: /content/dataset/Original/Training/22885.jpg
#   inflating: /content/dataset/Original/Training/27335.jpg
#   inflating: /content/dataset/Original/Training/2351.jpg
#   inflating: /content/dataset/Original/Training/20210.jpg
#   inflating: /content/dataset/Original/Training/13642.jpg
#   inflating: /content/dataset/Original/Training/21348.jpg
#   inflating: /content/dataset/Original/Training/26085.jpg
#   inflating: /content/dataset/Original/Training/6006.jpg
#   inflating: /content/dataset/Original/Training/11284.jpg
#   inflating: /content/dataset/Original/Training/4170.jpg
#   inflating: /content/dataset/Original/Training/3799.jpg
#   inflating: /content/dataset/Original/Training/15335.jpg
#   inflating: /content/dataset/Original/Training/28446.jpg
#   inflating: /content/dataset/Original/Training/16632.jpg
#   inflating: /content/dataset/Original/Training/25398.jpg
#   inflating: /content/dataset/Original/Training/16526.jpg
#   inflating: /content/dataset/Original/Training/5674.jpg
#   inflating: /content/dataset/Original/Training/22919.jpg
#   inflating: /content/dataset/Original/Training/11422.jpg
#   inflating: /content/dataset/Original/Training/24831.jpg
#   inflating: /content/dataset/Original/Training/26698.jpg
#   inflating: /content/dataset/Original/Training/22528.jpg
#   inflating: /content/dataset/Original/Training/7884.jpg
#   inflating: /content/dataset/Original/Training/3232.jpg
#   inflating: /content/dataset/Original/Training/19199.jpg
#   inflating: /content/dataset/Original/Training/9157.jpg
#   inflating: /content/dataset/Original/Training/22199.jpg
#   inflating: /content/dataset/Original/Training/2404.jpg
#   inflating: /content/dataset/Original/Training/19556.jpg
#   inflating: /content/dataset/Original/Training/16012.jpg
#   inflating: /content/dataset/Original/Training/24492.jpg
#   inflating: /content/dataset/Original/Training/24886.jpg
#   inflating: /content/dataset/Original/Training/15061.jpg
#   inflating: /content/dataset/Original/Training/27249.jpg
#   inflating: /content/dataset/Original/Training/8217.jpg
#   inflating: /content/dataset/Original/Training/7446.jpg
#   inflating: /content/dataset/Original/Training/10432.jpg
#   inflating: /content/dataset/Original/Training/4339.jpg
#   inflating: /content/dataset/Original/Training/12071.jpg
#   inflating: /content/dataset/Original/Training/26824.jpg
#   inflating: /content/dataset/Original/Training/23542.jpg
#   inflating: /content/dataset/Original/Training/7470.jpg
#   inflating: /content/dataset/Original/Training/15785.jpg
#   inflating: /content/dataset/Original/Training/15751.jpg
#   inflating: /content/dataset/Original/Training/18411.jpg
#   inflating: /content/dataset/Original/Training/24297.jpg
#   inflating: /content/dataset/Original/Training/8723.jpg
#   inflating: /content/dataset/Original/Training/13501.jpg
#   inflating: /content/dataset/Original/Training/9522.jpg
#   inflating: /content/dataset/Original/Training/9661.jpg
#   inflating: /content/dataset/Original/Training/19955.jpg
#   inflating: /content/dataset/Original/Training/7063.jpg
#   inflating: /content/dataset/Original/Training/5639.jpg
#   inflating: /content/dataset/Original/Training/2291.jpg
#   inflating: /content/dataset/Original/Training/16668.jpg
#   inflating: /content/dataset/Original/Training/19289.jpg
#   inflating: /content/dataset/Original/Training/7729.jpg
#   inflating: /content/dataset/Original/Training/14305.jpg
#   inflating: /content/dataset/Original/Training/20325.jpg
#   inflating: /content/dataset/Original/Training/26062.jpg
#   inflating: /content/dataset/Original/Training/5232.jpg
#   inflating: /content/dataset/Original/Training/7354.jpg
#   inflating: /content/dataset/Original/Training/24893.jpg
#   inflating: /content/dataset/Original/Training/15551.jpg
#   inflating: /content/dataset/Original/Training/18089.jpg
#   inflating: /content/dataset/Original/Training/14110.jpg
#   inflating: /content/dataset/Original/Training/12546.jpg
#   inflating: /content/dataset/Original/Training/16122.jpg
#   inflating: /content/dataset/Original/Training/28419.jpg
#   inflating: /content/dataset/Original/Training/6282.jpg
#   inflating: /content/dataset/Original/Training/18724.jpg
#   inflating: /content/dataset/Original/Training/1527.jpg
#   inflating: /content/dataset/Original/Training/23053.jpg
#   inflating: /content/dataset/Original/Training/24468.jpg
#   inflating: /content/dataset/Original/Training/10769.jpg
#   inflating: /content/dataset/Original/Training/2954.jpg
#   inflating: /content/dataset/Original/Training/17719.jpg
#   inflating: /content/dataset/Original/Training/15437.jpg
#   inflating: /content/dataset/Original/Training/1906.jpg
#   inflating: /content/dataset/Original/Training/5830.jpg
#   inflating: /content/dataset/Original/Training/19681.jpg
#   inflating: /content/dataset/Original/Training/8064.jpg
#   inflating: /content/dataset/Original/Training/11409.jpg
#   inflating: /content/dataset/Original/Training/26717.jpg
#   inflating: /content/dataset/Original/Training/12651.jpg
#   inflating: /content/dataset/Original/Training/21945.jpg
#   inflating: /content/dataset/Original/Training/13778.jpg
#   inflating: /content/dataset/Original/Training/29100.jpg
#   inflating: /content/dataset/Original/Training/3396.jpg
#   inflating: /content/dataset/Original/Training/8415.jpg
#   inflating: /content/dataset/Original/Training/23892.jpg
#   inflating: /content/dataset/Original/Training/11641.jpg
#   inflating: /content/dataset/Original/Training/24843.jpg
#   inflating: /content/dataset/Original/Training/3894.jpg
#   inflating: /content/dataset/Original/Training/20869.jpg
#   inflating: /content/dataset/Original/Training/1956.jpg
#   inflating: /content/dataset/Original/Training/2234.jpg
#   inflating: /content/dataset/Original/Training/4397.jpg
#   inflating: /content/dataset/Original/Training/10981.jpg
#   inflating: /content/dataset/Original/Training/26018.jpg
#   inflating: /content/dataset/Original/Training/6878.jpg
#   inflating: /content/dataset/Original/Training/17915.jpg
#   inflating: /content/dataset/Original/Training/3823.jpg
#   inflating: /content/dataset/Original/Training/5864.jpg
#   inflating: /content/dataset/Original/Training/16872.jpg
#   inflating: /content/dataset/Original/Training/29039.jpg
#   inflating: /content/dataset/Original/Training/21046.jpg
#   inflating: /content/dataset/Original/Training/21502.jpg
#   inflating: /content/dataset/Original/Training/7667.jpg
#   inflating: /content/dataset/Original/Training/2350.jpg
#   inflating: /content/dataset/Original/Training/17633.jpg
#   inflating: /content/dataset/Original/Training/14242.jpg
#   inflating: /content/dataset/Original/Training/15395.jpg
#   inflating: /content/dataset/Original/Training/19260.jpg
#   inflating: /content/dataset/Original/Training/5001.jpg
#   inflating: /content/dataset/Original/Training/25148.jpg
#   inflating: /content/dataset/Original/Training/21016.jpg
#   inflating: /content/dataset/Original/Training/19572.jpg
#   inflating: /content/dataset/Original/Training/16746.jpg
#   inflating: /content/dataset/Original/Training/10417.jpg
#   inflating: /content/dataset/Original/Training/14587.jpg
#   inflating: /content/dataset/Original/Training/10511.jpg
#   inflating: /content/dataset/Original/Training/28456.jpg
#   inflating: /content/dataset/Original/Training/11862.jpg
#   inflating: /content/dataset/Original/Training/24678.jpg
#   inflating: /content/dataset/Original/Training/Frame00067-org.jpg
#   inflating: /content/dataset/Original/Training/Frame00074-org.jpg
#   inflating: /content/dataset/Original/Training/Frame00078-org.jpg
#   inflating: /content/dataset/Original/Training/Frame00086-org.jpg
#   inflating: /content/dataset/Original/Training/Frame00908-org.jpg
#   inflating: /content/dataset/Original/Training/Frame00103-org.jpg
#   inflating: /content/dataset/Original/Training/Frame00117-org.jpg
#   inflating: /content/dataset/Original/Training/Frame00120-org.jpg
#   inflating: /content/dataset/Original/Training/Frame00125-org.jpg
#   inflating: /content/dataset/Original/Training/Frame00209-org.jpg
#   inflating: /content/dataset/Original/Training/Frame00214-org.jpg
#   inflating: /content/dataset/Original/Training/Frame00230-org.jpg
#   inflating: /content/dataset/Original/Training/Frame00243-org.jpg
#   inflating: /content/dataset/Original/Training/Frame00296-org.jpg
#   inflating: /content/dataset/Original/Training/Frame00349-org.jpg
#   inflating: /content/dataset/Original/Training/Frame00371-org.jpg
#   inflating: /content/dataset/Original/Training/Frame00468-org.jpg
#   inflating: /content/dataset/Original/Training/Frame00506-org.jpg
#   inflating: /content/dataset/Original/Training/Frame00619-org.jpg
#   inflating: /content/dataset/Original/Training/Frame00621-org.jpg
#   inflating: /content/dataset/Original/Training/Frame00682-org.jpg
#   inflating: /content/dataset/Original/Training/Frame00684-org.jpg
#   inflating: /content/dataset/Original/Training/Frame00691-org.jpg
#   inflating: /content/dataset/Original/Training/Frame00698-org.jpg
#   inflating: /content/dataset/Original/Training/Frame00713-org.jpg
#   inflating: /content/dataset/Original/Training/Frame00736-org.jpg
#   inflating: /content/dataset/Original/Training/Frame00750-org.jpg
#   inflating: /content/dataset/Original/Training/Frame00761-org.jpg
#   inflating: /content/dataset/Original/Training/Frame00774-org.jpg
#   inflating: /content/dataset/Original/Training/Frame00820-org.jpg
#   inflating: /content/dataset/Original/Training/Frame00878-org.jpg
#   inflating: /content/dataset/Original/Training/Frame00942-org.jpg
#   inflating: /content/dataset/Original/Training/Frame00949-org.jpg
#   inflating: /content/dataset/Original/Training/Frame00987-org.jpg
#   inflating: /content/dataset/Original/Training/Frame01014-org.jpg
#   inflating: /content/dataset/Original/Training/Frame01017-org.jpg
#   inflating: /content/dataset/Original/Training/Frame01021-org.jpg
#   inflating: /content/dataset/Original/Training/20911.jpg
#   inflating: /content/dataset/Original/Training/6458.jpg
#   inflating: /content/dataset/Original/Training/15978.jpg
#   inflating: /content/dataset/Original/Training/1147.jpg
#   inflating: /content/dataset/Original/Training/20094.jpg
#   inflating: /content/dataset/Original/Training/8697.jpg
#   inflating: /content/dataset/Original/Training/7749.jpg
#   inflating: /content/dataset/Original/Training/15092.jpg
#   inflating: /content/dataset/Original/Training/2228.jpg
#   inflating: /content/dataset/Original/Training/26429.jpg
#   inflating: /content/dataset/Original/Training/26810.jpg
#   inflating: /content/dataset/Original/Training/1194.jpg
#   inflating: /content/dataset/Original/Training/5248.jpg
#   inflating: /content/dataset/Original/Training/2098.jpg
#   inflating: /content/dataset/Original/Training/19442.jpg
#   inflating: /content/dataset/Original/Training/17374.jpg
#   inflating: /content/dataset/Original/Training/7601.jpg
#   inflating: /content/dataset/Original/Training/25951.jpg
#   inflating: /content/dataset/Original/Training/21667.jpg
#   inflating: /content/dataset/Original/Training/19470.jpg
#   inflating: /content/dataset/Original/Training/8700.jpg
#   inflating: /content/dataset/Original/Training/17372.jpg
#   inflating: /content/dataset/Original/Training/19286.jpg
#   inflating: /content/dataset/Original/Training/17658.jpg
#   inflating: /content/dataset/Original/Training/12107.jpg
#   inflating: /content/dataset/Original/Training/13946.jpg
#   inflating: /content/dataset/Original/Training/23634.jpg
#   inflating: /content/dataset/Original/Training/17059.jpg
#   inflating: /content/dataset/Original/Training/21940.jpg
#   inflating: /content/dataset/Original/Training/26349.jpg
#   inflating: /content/dataset/Original/Training/6960.jpg
#   inflating: /content/dataset/Original/Training/11199.jpg
#   inflating: /content/dataset/Original/Training/4683.jpg
#   inflating: /content/dataset/Original/Training/18405.jpg
#   inflating: /content/dataset/Original/Training/28104.jpg
#   inflating: /content/dataset/Original/Training/16181.jpg
#   inflating: /content/dataset/Original/Training/12975.jpg
#   inflating: /content/dataset/Original/Training/5491.jpg
#   inflating: /content/dataset/Original/Training/26078.jpg
#   inflating: /content/dataset/Original/Training/21764.jpg
#   inflating: /content/dataset/Original/Training/6655.jpg
#   inflating: /content/dataset/Original/Training/5427.jpg
#   inflating: /content/dataset/Original/Training/14279.jpg
#   inflating: /content/dataset/Original/Training/15970.jpg
#   inflating: /content/dataset/Original/Training/20900.jpg
#   inflating: /content/dataset/Original/Training/17646.jpg
#   inflating: /content/dataset/Original/Training/27405.jpg
#   inflating: /content/dataset/Original/Training/8554.jpg
#   inflating: /content/dataset/Original/Training/12972.jpg
#   inflating: /content/dataset/Original/Training/7816.jpg
#   inflating: /content/dataset/Original/Training/10584.jpg
#   inflating: /content/dataset/Original/Training/11634.jpg
#   inflating: /content/dataset/Original/Training/23499.jpg
#   inflating: /content/dataset/Original/Training/23140.jpg
#   inflating: /content/dataset/Original/Training/5104.jpg
#   inflating: /content/dataset/Original/Training/1066.jpg
#   inflating: /content/dataset/Original/Training/2659.jpg
#   inflating: /content/dataset/Original/Training/18503.jpg
#   inflating: /content/dataset/Original/Training/20190.jpg
#   inflating: /content/dataset/Original/Training/13350.jpg
#   inflating: /content/dataset/Original/Training/14347.jpg
#   inflating: /content/dataset/Original/Training/3900.jpg
#   inflating: /content/dataset/Original/Training/12987.jpg
#   inflating: /content/dataset/Original/Training/23998.jpg
#   inflating: /content/dataset/Original/Training/24598.jpg
#   inflating: /content/dataset/Original/Training/10740.jpg
#   inflating: /content/dataset/Original/Training/11340.jpg
#   inflating: /content/dataset/Original/Training/3311.jpg
#   inflating: /content/dataset/Original/Training/2641.jpg
#   inflating: /content/dataset/Original/Training/29977.jpg
#   inflating: /content/dataset/Original/Training/13149.jpg
#   inflating: /content/dataset/Original/Training/24148.jpg
#   inflating: /content/dataset/Original/Training/25167.jpg
#   inflating: /content/dataset/Original/Training/17555.jpg
#   inflating: /content/dataset/Original/Training/22223.jpg
#   inflating: /content/dataset/Original/Training/18480.jpg
#   inflating: /content/dataset/Original/Training/13860.jpg
#   inflating: /content/dataset/Original/Training/18768.jpg
#   inflating: /content/dataset/Original/Training/8334.jpg
#   inflating: /content/dataset/Original/Training/14309.jpg
#   inflating: /content/dataset/Original/Training/15718.jpg
#   inflating: /content/dataset/Original/Training/16977.jpg
#   inflating: /content/dataset/Original/Training/1224.jpg
#   inflating: /content/dataset/Original/Training/7860.jpg
#   inflating: /content/dataset/Original/Training/26236.jpg
#   inflating: /content/dataset/Original/Training/12914.jpg
#   inflating: /content/dataset/Original/Training/28659.jpg
#   inflating: /content/dataset/Original/Training/27221.jpg
#   inflating: /content/dataset/Original/Training/21331.jpg
#   inflating: /content/dataset/Original/Training/1196.jpg
#   inflating: /content/dataset/Original/Training/17516.jpg
#   inflating: /content/dataset/Original/Training/29817.jpg
#   inflating: /content/dataset/Original/Training/14354.jpg
#   inflating: /content/dataset/Original/Training/22844.jpg
#   inflating: /content/dataset/Original/Training/11586.jpg
#   inflating: /content/dataset/Original/Training/16775.jpg
#   inflating: /content/dataset/Original/Training/3942.jpg
#   inflating: /content/dataset/Original/Training/13663.jpg
#   inflating: /content/dataset/Original/Training/1587.jpg
#   inflating: /content/dataset/Original/Training/17828.jpg
#   inflating: /content/dataset/Original/Training/16696.jpg
#   inflating: /content/dataset/Original/Training/23617.jpg
#   inflating: /content/dataset/Original/Training/12480.jpg
#   inflating: /content/dataset/Original/Training/27706.jpg
#   inflating: /content/dataset/Original/Training/1371.jpg
#   inflating: /content/dataset/Original/Training/16691.jpg
#   inflating: /content/dataset/Original/Training/4491.jpg
#   inflating: /content/dataset/Original/Training/23147.jpg
#   inflating: /content/dataset/Original/Training/8196.jpg
#   inflating: /content/dataset/Original/Training/2959.jpg
#   inflating: /content/dataset/Original/Training/10333.jpg
#   inflating: /content/dataset/Original/Training/23452.jpg
#   inflating: /content/dataset/Original/Training/1934.jpg
#   inflating: /content/dataset/Original/Training/10058.jpg
#   inflating: /content/dataset/Original/Training/19335.jpg
#   inflating: /content/dataset/Original/Training/24878.jpg
#   inflating: /content/dataset/Original/Training/2222.jpg
#   inflating: /content/dataset/Original/Training/10284.jpg
#   inflating: /content/dataset/Original/Training/26759.jpg
#   inflating: /content/dataset/Original/Training/16239.jpg
#   inflating: /content/dataset/Original/Training/26721.jpg
#   inflating: /content/dataset/Original/Training/16084.jpg
#   inflating: /content/dataset/Original/Training/15008.jpg
#   inflating: /content/dataset/Original/Training/12889.jpg
#   inflating: /content/dataset/Original/Training/25793.jpg
#   inflating: /content/dataset/Original/Training/24570.jpg
#   inflating: /content/dataset/Original/Training/18132.jpg
#   inflating: /content/dataset/Original/Training/24372.jpg
#   inflating: /content/dataset/Original/Training/10974.jpg
#   inflating: /content/dataset/Original/Training/24434.jpg
#   inflating: /content/dataset/Original/Training/2619.jpg
#   inflating: /content/dataset/Original/Training/9551.jpg
#   inflating: /content/dataset/Original/Training/24693.jpg
#   inflating: /content/dataset/Original/Training/4203.jpg
#   inflating: /content/dataset/Original/Training/28856.jpg
#   inflating: /content/dataset/Original/Training/17116.jpg
#   inflating: /content/dataset/Original/Training/2866.jpg
#   inflating: /content/dataset/Original/Training/8145.jpg
#   inflating: /content/dataset/Original/Training/24781.jpg
#   inflating: /content/dataset/Original/Training/23025.jpg
#   inflating: /content/dataset/Original/Training/23721.jpg
#   inflating: /content/dataset/Original/Training/25960.jpg
#   inflating: /content/dataset/Original/Training/1873.jpg
#   inflating: /content/dataset/Original/Training/28139.jpg
#   inflating: /content/dataset/Original/Training/16234.jpg
#   inflating: /content/dataset/Original/Training/12565.jpg
#   inflating: /content/dataset/Original/Training/15367.jpg
#   inflating: /content/dataset/Original/Training/12666.jpg
#   inflating: /content/dataset/Original/Training/2638.jpg
#   inflating: /content/dataset/Original/Training/20775.jpg
#   inflating: /content/dataset/Original/Training/18851.jpg
#   inflating: /content/dataset/Original/Training/23788.jpg
#   inflating: /content/dataset/Original/Training/23577.jpg
#   inflating: /content/dataset/Original/Training/21572.jpg
#   inflating: /content/dataset/Original/Training/14151.jpg
#   inflating: /content/dataset/Original/Training/16533.jpg
#   inflating: /content/dataset/Original/Training/3273.jpg
#   inflating: /content/dataset/Original/Training/19227.jpg
#   inflating: /content/dataset/Original/Training/21959.jpg
#   inflating: /content/dataset/Original/Training/13546.jpg
#   inflating: /content/dataset/Original/Training/3074.jpg
#   inflating: /content/dataset/Original/Training/11907.jpg
#   inflating: /content/dataset/Original/Training/17274.jpg
#   inflating: /content/dataset/Original/Training/5804.jpg
#   inflating: /content/dataset/Original/Training/25848.jpg
#   inflating: /content/dataset/Original/Training/10843.jpg
#   inflating: /content/dataset/Original/Training/23926.jpg
#   inflating: /content/dataset/Original/Training/25133.jpg
#   inflating: /content/dataset/Original/Training/26460.jpg
#   inflating: /content/dataset/Original/Training/20901.jpg
#   inflating: /content/dataset/Original/Training/20805.jpg
#   inflating: /content/dataset/Original/Training/4551.jpg
#   inflating: /content/dataset/Original/Training/16521.jpg
#   inflating: /content/dataset/Original/Training/3859.jpg
#   inflating: /content/dataset/Original/Training/19614.jpg
#   inflating: /content/dataset/Original/Training/27033.jpg
#   inflating: /content/dataset/Original/Training/13657.jpg
#   inflating: /content/dataset/Original/Training/25078.jpg
#   inflating: /content/dataset/Original/Training/1452.jpg
#   inflating: /content/dataset/Original/Training/27653.jpg
#   inflating: /content/dataset/Original/Training/9991.jpg
#   inflating: /content/dataset/Original/Training/16933.jpg
#   inflating: /content/dataset/Original/Training/3075.jpg
#   inflating: /content/dataset/Original/Training/29850.jpg
#   inflating: /content/dataset/Original/Training/18879.jpg
#   inflating: /content/dataset/Original/Training/1497.jpg
#   inflating: /content/dataset/Original/Training/28147.jpg
#   inflating: /content/dataset/Original/Training/5686.jpg
#   inflating: /content/dataset/Original/Training/29848.jpg
#   inflating: /content/dataset/Original/Training/28891.jpg
#   inflating: /content/dataset/Original/Training/6934.jpg
#   inflating: /content/dataset/Original/Training/4591.jpg
#   inflating: /content/dataset/Original/Training/20465.jpg
#   inflating: /content/dataset/Original/Training/8683.jpg
#   inflating: /content/dataset/Original/Training/25158.jpg
#   inflating: /content/dataset/Original/Training/4706.jpg
#   inflating: /content/dataset/Original/Training/24386.jpg
#   inflating: /content/dataset/Original/Training/8007.jpg
#   inflating: /content/dataset/Original/Training/8608.jpg
#   inflating: /content/dataset/Original/Training/19540.jpg
#   inflating: /content/dataset/Original/Training/26734.jpg
#   inflating: /content/dataset/Original/Training/24230.jpg
#   inflating: /content/dataset/Original/Training/17163.jpg
#   inflating: /content/dataset/Original/Training/15682.jpg
#   inflating: /content/dataset/Original/Training/1895.jpg
#   inflating: /content/dataset/Original/Training/9189.jpg
#   inflating: /content/dataset/Original/Training/3259.jpg
#   inflating: /content/dataset/Original/Training/10626.jpg
# ...
#   inflating: /content/dataset/Original/Training/24234.jpg
#   inflating: /content/dataset/Original/Training/18640.jpg
#   inflating: /content/dataset/Original/Training/14167.jpg
#   inflating: /content/dataset/Original/Training/23600.jpg
#   inflating: /content/dataset/Original/Training/24594.jpg
#   inflating: /content/dataset/Original/Training/10946.jpg
#   inflating: /content/dataset/Original/Training/21571.jpg
#   inflating: /content/dataset/Original/Training/3945.jpg
#   inflating: /content/dataset/Original/Training/11374.jpg
#   inflating: /content/dataset/Original/Training/2324.jpg
#   inflating: /content/dataset/Original/Training/23257.jpg
#   inflating: /content/dataset/Original/Training/1440.jpg
#   inflating: /content/dataset/Original/Training/9703.jpg
#   inflating: /content/dataset/Original/Training/15515.jpg
#   inflating: /content/dataset/Original/Training/1963.jpg
#   inflating: /content/dataset/Original/Training/8537.jpg
#   inflating: /content/dataset/Original/Training/13294.jpg
#   inflating: /content/dataset/Original/Training/21079.jpg
#   inflating: /content/dataset/Original/Training/29642.jpg
#   inflating: /content/dataset/Original/Training/26976.jpg
#   inflating: /content/dataset/Original/Training/27177.jpg
#   inflating: /content/dataset/Original/Training/9480.jpg
#   inflating: /content/dataset/Original/Training/2486.jpg
#   inflating: /content/dataset/Original/Training/23865.jpg
#   inflating: /content/dataset/Original/Training/14518.jpg
#   inflating: /content/dataset/Original/Training/12205.jpg
#   inflating: /content/dataset/Original/Training/28477.jpg
#   inflating: /content/dataset/Original/Training/19054.jpg
#   inflating: /content/dataset/Original/Training/22233.jpg
#   inflating: /content/dataset/Original/Training/14385.jpg
#   inflating: /content/dataset/Original/Training/20891.jpg
#   inflating: /content/dataset/Original/Training/16499.jpg
#   inflating: /content/dataset/Original/Training/21301.jpg
#   inflating: /content/dataset/Original/Training/29659.jpg
#   inflating: /content/dataset/Original/Training/3691.jpg
#   inflating: /content/dataset/Original/Training/10492.jpg
#   inflating: /content/dataset/Original/Training/6765.jpg
#   inflating: /content/dataset/Original/Training/1853.jpg
#   inflating: /content/dataset/Original/Training/18109.jpg
#   inflating: /content/dataset/Original/Training/28436.jpg
#   inflating: /content/dataset/Original/Training/24316.jpg
#   inflating: /content/dataset/Original/Training/28552.jpg
#   inflating: /content/dataset/Original/Training/20322.jpg
#   inflating: /content/dataset/Original/Training/23901.jpg
#   inflating: /content/dataset/Original/Training/2947.jpg
#   inflating: /content/dataset/Original/Training/9443.jpg
#   inflating: /content/dataset/Original/Training/19174.jpg
#   inflating: /content/dataset/Original/Training/24966.jpg
#   inflating: /content/dataset/Original/Training/28486.jpg
#   inflating: /content/dataset/Original/Training/11370.jpg
#   inflating: /content/dataset/Original/Training/4952.jpg
#   inflating: /content/dataset/Original/Training/3748.jpg
#   inflating: /content/dataset/Original/Training/19217.jpg
#   inflating: /content/dataset/Original/Training/14550.jpg
#   inflating: /content/dataset/Original/Training/6535.jpg
#   inflating: /content/dataset/Original/Training/4318.jpg
#   inflating: /content/dataset/Original/Training/29224.jpg
#   inflating: /content/dataset/Original/Training/25529.jpg
#   inflating: /content/dataset/Original/Training/28991.jpg
#   inflating: /content/dataset/Original/Training/8556.jpg
#   inflating: /content/dataset/Original/Training/22778.jpg
#   inflating: /content/dataset/Original/Training/23422.jpg
#   inflating: /content/dataset/Original/Training/12400.jpg
#   inflating: /content/dataset/Original/Training/8453.jpg
#   inflating: /content/dataset/Original/Training/4836.jpg
#   inflating: /content/dataset/Original/Training/25655.jpg
#   inflating: /content/dataset/Original/Training/29519.jpg
#   inflating: /content/dataset/Original/Training/8663.jpg
#   inflating: /content/dataset/Original/Training/14114.jpg
#   inflating: /content/dataset/Original/Training/16969.jpg
#   inflating: /content/dataset/Original/Training/12749.jpg
#   inflating: /content/dataset/Original/Training/21482.jpg
#   inflating: /content/dataset/Original/Training/17626.jpg
#   inflating: /content/dataset/Original/Training/17497.jpg
#   inflating: /content/dataset/Original/Training/11896.jpg
#   inflating: /content/dataset/Original/Training/26927.jpg
#   inflating: /content/dataset/Original/Training/15409.jpg
#   inflating: /content/dataset/Original/Training/28645.jpg
#   inflating: /content/dataset/Original/Training/19538.jpg
#   inflating: /content/dataset/Original/Training/14725.jpg
#   inflating: /content/dataset/Original/Training/11556.jpg
#   inflating: /content/dataset/Original/Training/25948.jpg
#   inflating: /content/dataset/Original/Training/28688.jpg
#   inflating: /content/dataset/Original/Training/3148.jpg
#   inflating: /content/dataset/Original/Training/2146.jpg
#   inflating: /content/dataset/Original/Training/7593.jpg
#   inflating: /content/dataset/Original/Training/29189.jpg
#   inflating: /content/dataset/Original/Training/15587.jpg
#   inflating: /content/dataset/Original/Training/22468.jpg
#   inflating: /content/dataset/Original/Training/13340.jpg
#   inflating: /content/dataset/Original/Training/21376.jpg
#   inflating: /content/dataset/Original/Training/16035.jpg
#   inflating: /content/dataset/Original/Training/24015.jpg
#   inflating: /content/dataset/Original/Training/7781.jpg
#   inflating: /content/dataset/Original/Training/12955.jpg
#   inflating: /content/dataset/Original/Training/23058.jpg
#   inflating: /content/dataset/Original/Training/19477.jpg
#   inflating: /content/dataset/Original/Training/10053.jpg
#   inflating: /content/dataset/Original/Training/12790.jpg
#   inflating: /content/dataset/Original/Training/15296.jpg
#   inflating: /content/dataset/Original/Training/19729.jpg
#   inflating: /content/dataset/Original/Training/27876.jpg
#   inflating: /content/dataset/Original/Training/16448.jpg
#   inflating: /content/dataset/Original/Training/17974.jpg
#   inflating: /content/dataset/Original/Training/16353.jpg
#   inflating: /content/dataset/Original/Training/14197.jpg
#   inflating: /content/dataset/Original/Training/19495.jpg
#   inflating: /content/dataset/Original/Training/23062.jpg
#   inflating: /content/dataset/Original/Training/23153.jpg
#   inflating: /content/dataset/Original/Training/5721.jpg
#   inflating: /content/dataset/Original/Training/25882.jpg
#   inflating: /content/dataset/Original/Training/7992.jpg
#   inflating: /content/dataset/Original/Training/15249.jpg
#   inflating: /content/dataset/Original/Training/10249.jpg
#   inflating: /content/dataset/Original/Training/13531.jpg
#   inflating: /content/dataset/Original/Training/16261.jpg
#   inflating: /content/dataset/Original/Training/18638.jpg
#   inflating: /content/dataset/Original/Training/22409.jpg
#   inflating: /content/dataset/Original/Training/5752.jpg
#   inflating: /content/dataset/Original/Training/7828.jpg
#   inflating: /content/dataset/Original/Training/3537.jpg
#   inflating: /content/dataset/Original/Training/21413.jpg
#   inflating: /content/dataset/Original/Training/3350.jpg
#   inflating: /content/dataset/Original/Training/26580.jpg
#   inflating: /content/dataset/Original/Training/24759.jpg
#   inflating: /content/dataset/Original/Training/25202.jpg
#   inflating: /content/dataset/Original/Training/11753.jpg
#   inflating: /content/dataset/Original/Training/9024.jpg
#   inflating: /content/dataset/Original/Training/25952.jpg
#   inflating: /content/dataset/Original/Training/17625.jpg
#   inflating: /content/dataset/Original/Training/23013.jpg
#   inflating: /content/dataset/Original/Training/24535.jpg
#   inflating: /content/dataset/Original/Training/9033.jpg
#   inflating: /content/dataset/Original/Training/1496.jpg
#   inflating: /content/dataset/Original/Training/14697.jpg
#   inflating: /content/dataset/Original/Training/27115.jpg
#   inflating: /content/dataset/Original/Training/15375.jpg
#   inflating: /content/dataset/Original/Training/5078.jpg
#   inflating: /content/dataset/Original/Training/22852.jpg
#   inflating: /content/dataset/Original/Training/16715.jpg
#   inflating: /content/dataset/Original/Training/11897.jpg
#   inflating: /content/dataset/Original/Training/18841.jpg
#   inflating: /content/dataset/Original/Training/7837.jpg
#   inflating: /content/dataset/Original/Training/15146.jpg
#   inflating: /content/dataset/Original/Training/16783.jpg
#   inflating: /content/dataset/Original/Training/7445.jpg
#   inflating: /content/dataset/Original/Training/26570.jpg
#   inflating: /content/dataset/Original/Training/9613.jpg
#   inflating: /content/dataset/Original/Training/1283.jpg
#   inflating: /content/dataset/Original/Training/3698.jpg
#   inflating: /content/dataset/Original/Training/7217.jpg
#   inflating: /content/dataset/Original/Training/18274.jpg
#   inflating: /content/dataset/Original/Training/20211.jpg
#   inflating: /content/dataset/Original/Training/24019.jpg
#   inflating: /content/dataset/Original/Training/24924.jpg
#   inflating: /content/dataset/Original/Training/4894.jpg
#   inflating: /content/dataset/Original/Training/12210.jpg
#   inflating: /content/dataset/Original/Training/15428.jpg
#   inflating: /content/dataset/Original/Training/10774.jpg
#   inflating: /content/dataset/Original/Training/16579.jpg
#   inflating: /content/dataset/Original/Training/3388.jpg
#   inflating: /content/dataset/Original/Training/15865.jpg
#   inflating: /content/dataset/Original/Training/22168.jpg
#   inflating: /content/dataset/Original/Training/26995.jpg
#   inflating: /content/dataset/Original/Training/29700.jpg
#   inflating: /content/dataset/Original/Training/16247.jpg
#   inflating: /content/dataset/Original/Training/14058.jpg
#   inflating: /content/dataset/Original/Training/4122.jpg
#   inflating: /content/dataset/Original/Training/9879.jpg
#   inflating: /content/dataset/Original/Training/3687.jpg
#   inflating: /content/dataset/Original/Training/9022.jpg
#   inflating: /content/dataset/Original/Training/26238.jpg
#   inflating: /content/dataset/Original/Training/3265.jpg
#   inflating: /content/dataset/Original/Training/14032.jpg
#   inflating: /content/dataset/Original/Training/8612.jpg
#   inflating: /content/dataset/Original/Training/19296.jpg
#   inflating: /content/dataset/Original/Training/16189.jpg
#   inflating: /content/dataset/Original/Training/19539.jpg
#   inflating: /content/dataset/Original/Training/16079.jpg
#   inflating: /content/dataset/Original/Training/10236.jpg
#   inflating: /content/dataset/Original/Training/23494.jpg
#   inflating: /content/dataset/Original/Training/1172.jpg
#   inflating: /content/dataset/Original/Training/19154.jpg
#   inflating: /content/dataset/Original/Training/9116.jpg
#   inflating: /content/dataset/Original/Training/9291.jpg
#   inflating: /content/dataset/Original/Training/4875.jpg
#   inflating: /content/dataset/Original/Training/1490.jpg
#   inflating: /content/dataset/Original/Training/14045.jpg
#   inflating: /content/dataset/Original/Training/7698.jpg
#   inflating: /content/dataset/Original/Training/7998.jpg
#   inflating: /content/dataset/Original/Training/8866.jpg
#   inflating: /content/dataset/Original/Training/21369.jpg
#   inflating: /content/dataset/Original/Training/10380.jpg
#   inflating: /content/dataset/Original/Training/14317.jpg
#   inflating: /content/dataset/Original/Training/19432.jpg
#   inflating: /content/dataset/Original/Training/11718.jpg
#   inflating: /content/dataset/Original/Training/23244.jpg
#   inflating: /content/dataset/Original/Training/29234.jpg
#   inflating: /content/dataset/Original/Training/17264.jpg
#   inflating: /content/dataset/Original/Training/6808.jpg
#   inflating: /content/dataset/Original/Training/8653.jpg
#   inflating: /content/dataset/Original/Training/27225.jpg
#   inflating: /content/dataset/Original/Training/12466.jpg
#   inflating: /content/dataset/Original/Training/7447.jpg
#   inflating: /content/dataset/Original/Training/27444.jpg
#   inflating: /content/dataset/Original/Training/6587.jpg
#   inflating: /content/dataset/Original/Training/16370.jpg
#   inflating: /content/dataset/Original/Training/4118.jpg
#   inflating: /content/dataset/Original/Training/23636.jpg
#   inflating: /content/dataset/Original/Training/13537.jpg
#   inflating: /content/dataset/Original/Training/3718.jpg
#   inflating: /content/dataset/Original/Training/25376.jpg
#   inflating: /content/dataset/Original/Training/22682.jpg
#   inflating: /content/dataset/Original/Training/13863.jpg
#   inflating: /content/dataset/Original/Training/16334.jpg
#   inflating: /content/dataset/Original/Training/3325.jpg
#   inflating: /content/dataset/Original/Training/25997.jpg
#   inflating: /content/dataset/Original/Training/4853.jpg
#   inflating: /content/dataset/Original/Training/19344.jpg
#   inflating: /content/dataset/Original/Training/12770.jpg
#   inflating: /content/dataset/Original/Training/2110.jpg
#   inflating: /content/dataset/Original/Training/1807.jpg
#   inflating: /content/dataset/Original/Training/28338.jpg
#   inflating: /content/dataset/Original/Training/6646.jpg
#   inflating: /content/dataset/Original/Training/22658.jpg
#   inflating: /content/dataset/Original/Training/26778.jpg
#   inflating: /content/dataset/Original/Training/6780.jpg
#   inflating: /content/dataset/Original/Training/9758.jpg
#   inflating: /content/dataset/Original/Training/11434.jpg
#   inflating: /content/dataset/Original/Training/5192.jpg
#   inflating: /content/dataset/Original/Training/20408.jpg
#   inflating: /content/dataset/Original/Training/15633.jpg
#   inflating: /content/dataset/Original/Training/28196.jpg
#   inflating: /content/dataset/Original/Training/9655.jpg
#   inflating: /content/dataset/Original/Training/6640.jpg
#   inflating: /content/dataset/Original/Training/29199.jpg
#   inflating: /content/dataset/Original/Training/24375.jpg
#   inflating: /content/dataset/Original/Training/20767.jpg
#   inflating: /content/dataset/Original/Training/10898.jpg
#   inflating: /content/dataset/Original/Training/29257.jpg
#   inflating: /content/dataset/Original/Training/20328.jpg
#   inflating: /content/dataset/Original/Training/23811.jpg
#   inflating: /content/dataset/Original/Training/26011.jpg
#   inflating: /content/dataset/Original/Training/7250.jpg
#   inflating: /content/dataset/Original/Training/19140.jpg
#   inflating: /content/dataset/Original/Training/9127.jpg
#   inflating: /content/dataset/Original/Training/18686.jpg
#   inflating: /content/dataset/Original/Training/12232.jpg
#   inflating: /content/dataset/Original/Training/26330.jpg
#   inflating: /content/dataset/Original/Training/8199.jpg
#   inflating: /content/dataset/Original/Training/8373.jpg
#   inflating: /content/dataset/Original/Training/19445.jpg
#   inflating: /content/dataset/Original/Training/9716.jpg
#   inflating: /content/dataset/Original/Training/21910.jpg
#   inflating: /content/dataset/Original/Training/10323.jpg
#   inflating: /content/dataset/Original/Training/11929.jpg
#   inflating: /content/dataset/Original/Training/14760.jpg
#   inflating: /content/dataset/Original/Training/8844.jpg
#   inflating: /content/dataset/Original/Training/15371.jpg
#   inflating: /content/dataset/Original/Training/11424.jpg
#   inflating: /content/dataset/Original/Training/12438.jpg
#   inflating: /content/dataset/Original/Training/25060.jpg
#   inflating: /content/dataset/Original/Training/15122.jpg
#   inflating: /content/dataset/Original/Training/12203.jpg
#   inflating: /content/dataset/Original/Training/16568.jpg
#   inflating: /content/dataset/Original/Training/18090.jpg
#   inflating: /content/dataset/Original/Training/19701.jpg
#   inflating: /content/dataset/data.json

# %% [markdown]
# ### Xây dựng chương trình

# %%
import os 
import cv2
import json
import random
import numpy as np
from glob import glob
from os.path import join
import tensorflow as tf
import matplotlib.pyplot as plt
from tensorflow.keras.layers import Conv2D, Activation, BatchNormalization, MaxPool2D
from tensorflow.keras.layers import UpSampling2D, Input, Concatenate, Flatten
from tensorflow.keras.models import Model
from tensorflow.keras.utils import Sequence
from tensorflow.keras.applications import ResNet50
from tensorflow.keras.metrics import Recall, Precision

# %% [markdown]
# ### Load và Write json

# %%
def load_json(json_file):
    with open(json_file, 'r') as file:
        return json.loads(file.read())


def write_json(json_file, arr):
    with open(json_file, 'w') as file:
        json.dump(arr, file, indent=4)

# %% [markdown]
# ### Data Augmentation

# %%
class ToTensor(object):

    def __call__(self, img, mask):
        """
        Convert Image to Tensorflow Tensor
        :param img:
        :param mask:
        :return: img, mask
        """
        img = tf.convert_to_tensor(img)
        mask = tf.convert_to_tensor(mask)
        return img, mask


class Normalize(object):
    def __init__(self, std, mean):
        super(Normalize, self).__init__()
        self.std = std
        self.mean = mean

    def __call__(self, img, mask):
        """
        Normalize image with mean and std of imagenet dataset
        :param img:
        :param mask
        :return: img, mask
        """
        img = img / 255.0
        mask = mask / 255.0
        img -= self.mean
        img /= self.std
        return img, mask


class RandomFlip(object):

    def __call__(self, img, mask):
        """
        Flip image and mask, the image will be flipped hôintal, vertical or both
        :param img:
        :param mask:
        :return: img, mask
        """
        if random.choice([0, 1]):
            print(1)
            axis = random.choice([-1, 0, 1])
            img = cv2.flip(img, axis)
            mask = cv2.flip(img, axis)

        return img, mask


class Resize(object):
    def __init__(self, dim):
        super(Resize, self).__init__()
        self.dim = dim

    def __call__(self, img, mask):
        """
        Resize image with shape(width, height)
        :param img:
        :param mask:
        :return: img, mask
        """
        img = cv2.resize(img, self.dim)
        mask = cv2.resize(mask, self.dim)
        return img, mask


class RandomRotate(object):
    def __call__(self, img, mask):
        """
        Rotate image with random degree
        :param img:
        :param mask:
        :return:
        """
        degree = random.uniform(0, 360)
        h, w = img.shape[:2]
        c = cv2.getRotationMatrix2D((w/2, h/2), degree, scale=1.0)

        img = cv2.warpAffine(img, c, img.shape[:2])
        mask = cv2.warpAffine(mask, c, img.shape[:2])

        return img, mask


class RandomCrop(object):
    def __init__(self, dim):
        super(RandomCrop, self).__init__()
        self.dim = dim

    def __call__(self, img, mask):
        """
        Crop image with fixed shape and random
        :param img:
        :param mask:
        :return: img, mask
        """
        h, w = img.shape[:2]
        y = random.randint(0, h - self.dim[1])
        x = random.randint(0, w - self.dim[0])

        img = img[y:y+self.dim[1], x:x + self.dim[0]]
        mask = mask[y:y + self.dim[1], x:x + self.dim[0]]

        return img, mask


class RandomGaussianBlur(object):

    def __call__(self, img, mask):
        '''
        Blur image using Gaussian with random radius
        :param img:
        :param mask:
        :return: img, mask
        '''
        if random.choice([0, 1]):
            radius = random.choice([1, 3, 5])
            img = cv2.GaussianBlur(img, (radius, radius), 0)

        return img, mask


class ChangeBrightness(object):

    def __call__(self, img, mask):
        """
        Change Brightness of image, image can be brighter, darker or not
        :param img:
        :param mask:
        :return: img, mask
        """
        if random.choice([0, 1]):
            lookUpTable = np.empty((1, 256), np.uint8)
            gamma = random.uniform(0.1, 3)
            for i in range(256):
                lookUpTable[0, i] = np.clip(pow(i / 255.0, gamma) * 255.0, 0, 255)
            img = cv2.LUT(img, lookUpTable)

        return img, mask

# %% [markdown]
# ### Data Generator
#
# Xây dựng chương trình loader cho dữ liệu

# %%
class Dataset(Sequence):
    def __init__(self, imgs, phase='Training', batch_size=8):
        self.phase = phase
        self.batch_size = batch_size
        self.imgs = imgs


    def load_data(self, imgs_batch):
        imgs = list()
        masks = list()

        for img_name in imgs_batch:
            img_path = join(img_paths, self.phase, img_name)
            mask_path = join(mask_paths, self.phase, img_name.split('.')[0] + '.png')

            img = cv2.imread(img_path)
            mask = cv2.imread(mask_path)

            if self.phase == 'Training':
                img, mask = self.train_transform(img, mask)
            else:
                img, mask = self.val_transfrom(img, mask)

            imgs.append(img)
            masks.append(mask)

        imgs = tf.convert_to_tensor(imgs)
        masks = tf.convert_to_tensor(masks)

        return imgs, masks


    def train_transform(self, img, mask):
        img, mask = Resize(dim=(256, 256))(img, mask)
        img, mask = RandomRotate()(img, mask)
        img, mask = ChangeBrightness()(img, mask)
        img, mask = RandomGaussianBlur()(img, mask)
        img, mask = RandomCrop(dim=(224, 224))(img, mask)
        img, mask = Normalize(std=[0.229, 0.224, 0.225],
                              mean=[0.485, 0.456, 0.406])(img, mask)
        img, mask = ToTensor()(img, mask[:, :, 0])

        return img, mask


    def val_transfrom(self, img, mask):
        img, mask = Resize(dim=(256, 256))(img, mask)
        img, mask = RandomCrop(dim=(224, 224))(img, mask)
        img, mask = Normalize(std=[0.229, 0.224, 0.225],
                              mean=[0.485, 0.456, 0.406])(img, mask)
        img, mask = ToTensor()(img, mask[:, :, 0])

        return img, mask


    def __getitem__(self, index):

        stop = (index + 1)*self.batch_size

        if stop > len(self.imgs):
            stop = len(self.imgs)

        imgs_batch = self.imgs[index*self.batch_size:stop]
        imgs, masks = self.load_data(imgs_batch)

        return imgs, masks


    def __len__(self):
        return int(np.ceil(len(self.imgs) / self.batch_size))

# %% [markdown]
# ### Mô hình
#
# Xây dựng kiến trúc cho mô hình hair segmentation.
#
# Kiến trúc: Unet

# %%
def conv_block(filters, x):
    x = Conv2D(filters=filters, 
                kernel_size=(3,3), 
                padding='same', 
                activation='relu')(x)

    x = BatchNormalization()(x)

    x = Conv2D(filters=filters, 
                kernel_size=(3,3), 
                padding='same', 
                activation='relu')(x)
    out = BatchNormalization()(x)
    return out 


def down_sample(filters, x):
    x = MaxPool2D((2,2))(x)
    out = conv_block(filters, x)
    return out


def up_sample(filters, x, x1):
    x = Conv2D(filters=filters,
                kernel_size=(2,2),
                padding='same',
                activation='relu')(x)

    x = UpSampling2D((2, 2))(x)
    x = Concatenate()([x1, x])
    out = conv_block(filters, x)
    return out

def Unet():

    # Encoder
    inputs = Input(shape=(224, 224, 3), name="input_image")
    down1 = conv_block(64, inputs)
    down2 = down_sample(128, down1)
    down3 = down_sample(256, down2)
    down4 = down_sample(512, down3)
    down5 = down_sample(1024, down4)

    # Decoder
    up1 = up_sample(512, down5, down4)
    up2 = up_sample(256, up1, down3)
    up3 = up_sample(128, up2, down2)
    up4 = up_sample(64, up3, down1)

    out = Conv2D(filters=1,
                kernel_size=(1,1),
                padding='same',
                activation='sigmoid')(up4)

    model = Model(inputs, out)
    
    return model

# %% [markdown]
# ### Metrics

# %%
smooth = 1e-15
def iou(y_true, y_pred):
  y_true = tf.keras.layers.Flatten()(y_true)
  y_pred = tf.keras.layers.Flatten()(y_pred)
  intersection = tf.reduce_sum(y_true * y_pred)
  union = tf.reduce_sum(y_true) + tf.reduce_sum(y_pred) - intersection
  return (intersection + smooth) / (union + smooth)

def iou_loss(y_true, y_pred):
  return 1.0 - iou(y_true, y_pred)

# %% [markdown]
# ### Huấn luyện mô hình

# %%
img_paths = 'dataset/Original'
mask_paths = 'dataset/MASKS'
model_path = 'trained_model/hair_segmentation.h5'
json_path = 'dataset/data.json'

# %%
# Tham số huấn luyện mô hình 
batch_size = 32
lr = 1e-3
epochs = 10
momentum = 0.9
num_classes = 1

# %%
# Load dữ liệu 
data = load_json(json_path)
test_loader = Dataset(data['test'], phase='Testing', batch_size=batch_size)
train_loader = Dataset(data['train'], phase='Training', batch_size=batch_size)

# %%
import tensorflow.keras.backend

K = tf.keras.backend.backend()
if K=='tensorflow':
    tf.keras.backend.set_image_data_format("channels_last")

# %%
# load model
model = Unet()

losses = tf.keras.losses.BinaryCrossentropy()
optimizer = tf.keras.optimizers.SGD(learning_rate=lr, momentum=momentum)
metrics = [iou, Recall(), Precision()]

# %%
# Lập lịch cho learning rate
def scheduler(epoch, lr):
  if epoch < 4:
    return lr
  else:
    return lr * tf.math.exp(-0.1)

# %%
# huấn luyện 
model.compile(optimizer=optimizer, loss=iou_loss, metrics=metrics)
callback = tf.keras.callbacks.LearningRateScheduler(scheduler)

model.fit_generator(train_loader,
                    steps_per_epoch=len(train_loader),
                    epochs=epochs,
                    callbacks=[callback],
                    validation_data=test_loader,
                    validation_steps=len(test_loader))
# Out:
# Epoch 1/10
#  72/733 [=>............................] - ETA: 7:59 - loss: 0.5987 - iou: 0.4012 - recall_1: 0.7467 - precision_1: 0.4984

# %%
model.save(model_path)

# %% [markdown]
# ### Download model

# %%
from google.colab import files
files.download(model_path)

# %% [markdown]
# ### Test mô hình

# %%
def preprocessing(img):
  img, mask = Resize(dim=(224, 224))(img, img)
  img, mask = Normalize(std=[0.229, 0.224, 0.225],
                        mean=[0.485, 0.456, 0.406])(img, mask)
  img, _ = ToTensor()(img, mask[:, :, 0])

  return img

# %%
img = cv2.imread('/content/dataset/Original/Testing/Frame00583-org.jpg')
img1 = preprocessing(img)
img1 = tf.expand_dims(img1, axis=0)

# %%
mask = model.predict(img1)

# %%
mask_ = np.squeeze(mask)

# %%
plt.imshow(np.ndarray.astype(mask_*255, np.uint8), cmap='gray')

# %%
plt.imshow(cv2.cvtColor(img, cv2.COLOR_BGR2RGB))
